# %%
import pandas as pd
import requests

# %%
url = "https://api.themoviedb.org/3/discover/movie"
headers = {
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlOWMzMzg5YzI0NzRhNjFkYjM0NjY3ZTgxMjQ0MDg4ZCIsIm5iZiI6MTc2NTAzNzY3MS4yOTksInN1YiI6IjY5MzQ1NjY3NDkzY2EwZTE1OTcwYThhNCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.-ytYXQjK8F79blOC07BwG3Sw7dtE0GhyWbhkP2e72e0",
    "accept": "application/json"
}
params = {
    "include_adult": "false",
    "include_video": "false",
    "language": "en-US",
    "page": 1,
    "sort_by": "vote_average.desc",
    "without_genres": "99,10755",
    "vote_count.gte": 200
}

response = requests.get(url, headers=headers, params=params)
data = response.json()

# %%
df = pd.DataFrame(data["results"])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
df.head()
# Out:
#         id                     title  \
# 0      278  The Shawshank Redemption
# 1      238             The Godfather
# 2      240     The Godfather Part II
# 3      424          Schindler's List
# 4  1181678     ¿Quieres ser mi hijo?
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     26.1578
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     25.6928
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     16.7535
# 3  The true story of how businessman Oskar Schind...   1993-12-15     10.8518
# 4  Lu, a conformist woman in her forties, learns ...   2023-09-21      1.9569
#
#    vote_average  vote_count
# 0         8.713       29312
# 1         8.685       22122
# 2         8.570       13373
# 3         8.566       16887
# 4         8.562         291

# %%
df=pd.DataFrame()

# %%
url = "https://api.themoviedb.org/3/discover/movie"
headers = {
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlOWMzMzg5YzI0NzRhNjFkYjM0NjY3ZTgxMjQ0MDg4ZCIsIm5iZiI6MTc2NTAzNzY3MS4yOTksInN1YiI6IjY5MzQ1NjY3NDkzY2EwZTE1OTcwYThhNCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.-ytYXQjK8F79blOC07BwG3Sw7dtE0GhyWbhkP2e72e0",
    "accept": "application/json"
    }
for i in range(1,429):
    
    params = {
    "include_adult": "false",
    "include_video": "false",
    "language": "en-US",
    "page": i,
    "sort_by": "vote_average.desc",
    "without_genres": "99,10755",
    "vote_count.gte": 200
    }

    response = requests.get(url, headers=headers, params=params)
    data = response.json()

    if "results" not in data:
        print("❌ No 'results' key in response. Full response:")
        print(data)
    else:
        temp_df = pd.DataFrame(data["results"])[[
            'id','title','overview','release_date','popularity','vote_average','vote_count'
        ]]
        df = pd.concat([df, temp_df], ignore_index=True)

# %%
df.shape
# Out:
# (15700, 7)

# %%
df.head()
# Out:
#         id                     title  \
# 0      278  The Shawshank Redemption
# 1      238             The Godfather
# 2      240     The Godfather Part II
# 3      424          Schindler's List
# 4  1181678     ¿Quieres ser mi hijo?
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     26.1578
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     25.6928
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     16.7535
# 3  The true story of how businessman Oskar Schind...   1993-12-15     10.8518
# 4  Lu, a conformist woman in her forties, learns ...   2023-09-21      1.9569
#
#    vote_average  vote_count
# 0         8.713       29312
# 1         8.685       22122
# 2         8.570       13373
# 3         8.566       16887
# 4         8.562         291

# %%
df.to_csv("movie.csv")
