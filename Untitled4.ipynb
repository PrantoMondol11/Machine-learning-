# %% [markdown]
# <a href="https://colab.research.google.com/github/PrantoMondol11/Machine-learning-/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
class Mul_lr:
  def __init__(self):
    self.coef=None
    self.intercept=None
  def fit(self,X_train,y_train):
    X_train=np.insert(X_train,0,1,axis=1)
    betas=np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
    self.coef=betas[1:]
    self.intercept=betas[0]
  def pred(self,X_test):
    y_pred=np.dot(X_test,self.coef)+self.intercept
    return y_pred

X = np.array([[1], [2], [3]])
y = np.array([2, 3, 4])

model = Mul_lr()
model.fit(X, y)

X_test = np.array([[4]])
print(model.pred(X_test))
# Out:
# [5.]
