# %% [markdown]
# <a href="https://colab.research.google.com/github/PrantoMondol11/Machine-learning-/blob/main/torch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
x=torch.rand(2,2)

# %%
x
# Out:
# tensor([[0.0517, 0.4568],
#         [0.8514, 0.2430]])

# %%
x+2
# Out:
# tensor([[2.0517, 2.4568],
#         [2.8514, 2.2430]])
