# %% [markdown]
# <a href="https://colab.research.google.com/github/PrantoMondol11/Machine-learning-/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
class GBreg:
  def __init__(self,lr=.01,ep=100):
    self.coe=None
    self.inter=None
    self.lr=lr
    self.ep=ep
    def fit(self,X_train,y_train):
      self.inter=0
      self.coe=np.ones(X_train.shape[1])
      for i in range(self.ep):
          y_hat=np.dot(X_train,self.coe)+self.inter
          inter_df=-2*np.mean(y_train - y_hat)
          self.inter=self.inter-(self.lr*inter_df)

          cor_df=-2*np.dot((y_train-y_hat),X_train)/X_traon.shape[0]
          self.coe=self.coe-(self.lr*coe_df)
    def predict(self,X_test):
        return np.dot(X_test,self.coe)+ self.intercept

# %%
gdr=GBreg(ep=1000,lr=.5)
gdr.fit()
